# %% [markdown]
# # Phase 1 exploration
# Ask it 10 real revision questions from one course; note every wrong or hallucinated answer (roadmap section 7).

# %%
import sys
sys.path.insert(0, "..")

from src.rag import rag_query

# %%
result = rag_query("Your question here")
print(result["answer"])
for s in result["sources"]:
    print(s["source_file"], "p.", s["page"])
